      4050  -5.2721773e+10  20401409      -5.2701372e+10  300.18642      5396.6896      1.7280869e+08  1.0950832    
      4100  -5.2721846e+10  20401155      -5.2701445e+10  300.18267      5396.6222      1.7280869e+08  1.0950832    
      4150  -5.2721911e+10  20404730      -5.2701507e+10  300.23528      5397.568       1.7280869e+08  1.0950832    
      4200  -5.2721979e+10  20399551      -5.2701579e+10  300.15908      5396.198       1.7280869e+08  1.0950832    
      4250  -5.2722043e+10  20400724      -5.2701642e+10  300.17634      5396.5084      1.7280869e+08  1.0950832    
      4300  -5.2722107e+10  20403767      -5.2701703e+10  300.22112      5397.3133      1.7280869e+08  1.0950832    
      4350  -5.2722173e+10  20405643      -5.2701768e+10  300.24871      5397.8095      1.7280869e+08  1.0950832    
      4400  -5.2722231e+10  20407118      -5.2701824e+10  300.27042      5398.1997      1.7280869e+08  1.0950832    
      4450  -5.27223e+10    20400012      -5.27019e+10    300.16585      5396.3198      1.7280869e+08  1.0950832    
      4500  -5.2722358e+10  20403201      -5.2701955e+10  300.21278      5397.1636      1.7280869e+08  1.0950832    
      4550  -5.2722421e+10  20403418      -5.2702017e+10  300.21597      5397.2209      1.7280869e+08  1.0950832    
      4600  -5.2722474e+10  20405404      -5.2702069e+10  300.24519      5397.7462      1.7280869e+08  1.0950832    
      4650  -5.2722531e+10  20398550      -5.2702132e+10  300.14434      5395.9331      1.7280869e+08  1.0950832    
      4700  -5.2722593e+10  20397194      -5.2702196e+10  300.12439      5395.5745      1.7280869e+08  1.0950832    
      4750  -5.2722652e+10  20398547      -5.2702253e+10  300.1443       5395.9323      1.7280869e+08  1.0950832    
      4800  -5.2722711e+10  20404250      -5.2702306e+10  300.22821      5397.4409      1.7280869e+08  1.0950832    
      4850  -5.2722759e+10  20401845      -5.2702358e+10  300.19284      5396.8049      1.7280869e+08  1.0950832    
      4900  -5.2722824e+10  20402736      -5.2702421e+10  300.20594      5397.0405      1.7280869e+08  1.0950832    
      4950  -5.2722872e+10  20394046      -5.2702478e+10  300.07808      5394.7418      1.7280869e+08  1.0950832    
      5000  -5.2722933e+10  20400960      -5.2702532e+10  300.1798       5396.5706      1.7280869e+08  1.0950832   
"""

# %%
import re
import pandas as pd
# Adjusting the regex pattern to capture all the columns: Step, PotEng, KinEng, TotEng, Temp, Press, Volume, Density
pattern = r"(\d+)\s+(-?\d+\.\d+e[+-]\d+)\s+(\d+\.?\d*)\s+(-?\d+\.\d+e[+-]\d+)\s+(\d+\.\d+)\s+(\d+\.\d+)\s+(\d+\.\d+e[+-]\d+)\s+(\d+\.\d+)"

# Use regex to extract all columns
matches = re.findall(pattern, data)

# Create dataframe with appropriate columns
df = pd.DataFrame(matches, columns=['Step', 'PotEng', 'KinEng', 'TotEng', 'Temp', 'Press', 'Volume', 'Density'])

# Convert all columns to appropriate numeric types
df = df.astype({
    'Step': 'int',
    'PotEng': 'float',
    'KinEng': 'float',
    'TotEng': 'float',
    'Temp': 'float',
    'Press': 'float',
    'Volume': 'float',
    'Density': 'float'
})

df
# Out:
#     Step        PotEng      KinEng        TotEng       Temp      Press  \
# 0     50 -5.267587e+10  25992759.0 -5.264988e+10  382.45757  6875.7433
# 1    100 -5.268847e+10  22117546.0 -5.266636e+10  325.43766  5850.6512
# 2    150 -5.269371e+10  21270008.0 -5.267244e+10  312.96699  5626.4560
# 3    200 -5.269705e+10  20994934.0 -5.267605e+10  308.91954  5553.6919
# 4    250 -5.269952e+10  20852747.0 -5.267867e+10  306.82741  5516.0798
# ..   ...           ...         ...           ...        ...        ...
# 95  4800 -5.272271e+10  20404250.0 -5.270231e+10  300.22821  5397.4409
# 96  4850 -5.272276e+10  20401845.0 -5.270236e+10  300.19284  5396.8049
# 97  4900 -5.272282e+10  20402736.0 -5.270242e+10  300.20594  5397.0405
# 98  4950 -5.272287e+10  20394046.0 -5.270248e+10  300.07808  5394.7418
# 99  5000 -5.272293e+10  20400960.0 -5.270253e+10  300.17980  5396.5706
#
#          Volume   Density
# 0   172808690.0  1.095083
# 1   172808690.0  1.095083
# 2   172808690.0  1.095083
# ...

# %%
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams["font.size"] = 14
plt.rcParams["figure.figsize"] = (10,6)
plt.rcParams["figure.dpi"] = 200
purple = "#967BB6"

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df['Step'], df['Temp'], marker='.', linestyle='--', color=purple)
plt.xlabel('Step')
plt.ylabel('Temperature (K)')
plt.grid(True)
plt.tight_layout()
plt.savefig('steps_vs_temp_quench.png')
plt.show()

# %%
quench_mol = pd.read_parquet('quench_analysis/combined_415_quenched_molecule.pq')
quench_formula = pd.read_parquet('quench_analysis/combined_415_quenched_formula.pq')

original_mol = pd.read_parquet('quench_analysis/combined_415_original_molecule.pq')
original_formula = pd.read_parquet('quench_analysis/combined_415_original_formula.pq')

# %%
# Count the number of molecules per frame in quench_mol
molecule_counts = quench_mol.groupby('frame').size()

# Plotting number of molecules vs frame
plt.figure(figsize=(10, 6))
plt.plot(molecule_counts.index, molecule_counts.values, label="Number of Molecules", marker='.', linestyle='--')
plt.axvline(x=20, color='red', linestyle='--', label='Step 1000')
plt.xlabel("Frame")
plt.ylabel("Count")
plt.title("Number of Molecules vs Frame")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Count the number of molecules per frame in both datasets
quench_mol_counts = quench_mol.groupby('frame').size()
original_mol_counts = original_mol.groupby('frame').size()

plt.figure(figsize=(10, 6))

# Scatter plot for original molecules in blue
plt.scatter(original_mol_counts.index, original_mol_counts.values, 
            label="Original", color='blue', alpha=0.7, s=10)

# Scatter plot for quenched molecules in orange
plt.scatter(quench_mol_counts.index, quench_mol_counts.values, 
            label="Quenched", color='orange', alpha=0.7, s=10)

# Labels and title
plt.xlabel("Frame")
plt.ylabel("Number of Molecules")
plt.title("Number of Molecules vs Frame")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)

# Show plot
plt.show()

# %%
# Count the number of unique formulas per frame in quench_formula
formula_counts = quench_formula.groupby('frame').size()

plt.figure(figsize=(10, 6))
plt.plot(formula_counts.index, formula_counts.values, label="Number of Formulas", marker='.', linestyle='')
plt.xlabel("Frame")
plt.ylabel("Count")
plt.title("Number of Formulas vs Frame")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Count the number of unique formulas per frame in both datasets
quench_formula_counts = quench_formula.groupby('frame').size()
original_formula_counts = original_formula.groupby('frame').size()

plt.figure(figsize=(10, 6))

# Plot original formula counts in blue
plt.plot(original_formula_counts.index, original_formula_counts.values, 
         label="Original", marker='.', linestyle='', color='blue', alpha=0.7)

# Plot quenched formula counts in orange
plt.plot(quench_formula_counts.index, quench_formula_counts.values, 
         label="Quenched", marker='.', linestyle='', color='orange', alpha=0.7)

# Labels and title
plt.xlabel("Frame")
plt.ylabel("Number of Unique Formulas")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.savefig('quench_formula_vs_frame.png')
plt.show()

# %%
# Out:
#         frame  formula flatten_formula       smiles     name  \
# 0      224713  C3H7NO2   CCCHHHHHHHNOO  CC(C(=O)O)N  Alanine
# 1      224713  C3H7NO2   CCCHHHHHHHNOO  CC(C(=O)O)N  Alanine
# 2      224713  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 3      224713  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 4      224713  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# ...       ...      ...             ...          ...      ...
# 12425  100287  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 12426  100287  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 12427  100287  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 12428  100287  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 12429  100287  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
#
#                                             atom_indices
# 0      [431696, 2972081, 3725516, 5842740, 6476561, 6...
# 1      [353544, 1145124, 4559774, 5346574, 6559748, 8...
# 2      [856989, 4601145, 7589286, 8732939, 9458625, 1...
# ...

# %%
print('Formulas in last frame of quench:',len(quench_formula[quench_formula['frame'] == 100]))
quench_formula[quench_formula['frame'] == 100]
# Out:
# Formulas in last frame of quench: 0
# Empty DataFrame
# Columns: [index, counts, frame]
# Index: []

# %%
print('Molecules in original frame:',len(original_mol))
original_mol
# Out:
# Molecules in original frame: 7296
#        frame  formula flatten_formula       smiles     name  \
# 0     224713  C3H7NO2   CCCHHHHHHHNOO  CC(C(=O)O)N  Alanine
# 1     224713  C3H7NO2   CCCHHHHHHHNOO  CC(C(=O)O)N  Alanine
# 2     224713  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 3     224713  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 4     224713  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# ...      ...      ...             ...          ...      ...
# 7291  100287  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 7292  100287  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 7293  100287  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 7294  100287  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
# 7295  100287  C2H5NO2      CCHHHHHNOO   C(C(=O)O)N  Glycine
#
#                                            atom_indices
# 0     [353544, 1145124, 4559774, 5346574, 6559748, 8...
# 1     [3091795, 4883584, 6693908, 9467811, 9511606, ...
# ...

# %%
print('Formulas in original frame:',len(original_formula))
original_formula
# Out:
# Formulas in original frame: 708801
#                                           index   counts   frame
# 0                                           HHO  1733413  224713
# 1                                         CHHHH   892704  224713
# 2                                             H   857336  224713
# 3                                          HHHN   794904  224713
# 4                                            HH   649692  224713
# ...                                         ...      ...     ...
# 708796            CCCCCCCCCCCHHHHHHHHHHHHHHHHHH        1  100287
# 708797                            CCCHHHHHNNNOO        1  100287
# 708798                     CCCCCCCCHHHHHHHHHNNN        1  100287
# 708799  CCCCCCCCCCCCCCCHHHHHHHHHHHHHHHHHHHHHHNN        1  100287
# 708800                CCCCCCCCHHHHHHHHHHHHHNNNO        1  100287
#
# [708801 rows x 3 columns]
